# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import os
import av
from PIL import Image
sns.set_style('whitegrid')
# %matplotlib inline

# %%
VIDEO_PATH = 'data/train_videos/1948 - So Dear to My Heart.mp4'

# %%
from vzam import *

# %%
arrays = np.array([
  [[16, 16],
   [32, 32]],
   
  [[16, 32],
   [32, 16]], 
])

exponentially_weighted_average(arrays/256, 1.65)

# %%
processed_video_path = './.tmp/' + '_' + os.path.basename(VIDEO_PATH)
# preprocess_video(VIDEO_PATH, processed_video_path)
tiris = extract_tiri(processed_video_path, buffer_size=20)
for t in tiris[:100]:
    plt.imshow(t,  cmap='gray', vmin=0, vmax=1)
    plt.show()
